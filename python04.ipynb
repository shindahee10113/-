# %% [markdown]
# <a href="https://colab.research.google.com/github/shindahee10113/-/blob/main/python04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 시각화 모듈

# %% [markdown]
# * 코랩 환경에서 한글 폰트 사용하기

# %%
#한글 폰트 사용 : colab , 런타임 다시 시작 하기
# %config InlineBackend.figure_format = 'retina'

# !apt -qq -y install fonts-nanum
# Out:
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 34 not upgraded.
# Need to get 9,604 kB of archives.
# After this operation, 29.5 MB of additional disk space will be used.
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 160706 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20170925-1_all.deb ...
# Unpacking fonts-nanum (20170925-1) ...
# Setting up fonts-nanum (20170925-1) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...

# %%
# 경고메시지 숨김
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## matplotlib.pyplot

# %%
import matplotlib.pyplot as plt

import matplotlib as mpl
import matplotlib.font_manager as fm
fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=9)
plt.rc('font', family='NanumBarunGothic') 
mpl.font_manager._rebuild()

# %%
# 기온
temp = [10.8, 8.5, 8.7, 7.9, 5.1, 
        8.1, 8.2, 10.4, 11, 9.9, 
        7.8, 9.5, 11.6, 8.2, 7.7, 
        6.6, 11.1, 12.2, 12.6, 10.4, 
        13.7, 14.1, 12.6, 11.5, 13, 
        14.5, 13.7, 9.4, 10.4, 11.6, 12.9]

# %% [markdown]
# ### 기본그래프 그리기

# %%
plt.plot(temp)
plt.show()

# %% [markdown]
# ### 그래프 제목 추가하기

# %%
#그래프 제목 달기
plt.title('3월 기온') 
plt.xlabel('날짜')
plt.ylabel('기온')

plt.plot(temp)
plt.show()

# %% [markdown]
# ### 선 모양 정하기
# #### **선 옵션**
# + **색상**
#  - b(파란색), g(초록색), r(빨간색), c(청록색), y(노란색), k(검은색), w(흰색)
# + **마커**
#  - o(원), v(역삼각형), ^(삼각형), s(네모), +(플러스), .(점)
# + **선스타일**
#  - \-(solid line), --(dashed line ), -. (dash-dot line), : (dotted line )

# %%
# 선옵션
plt.plot(temp, 'go--')
plt.show()

# %% [markdown]
# ### 그래프 크기 조절
# + plt.figure()
#  - figsize를 이용하여 가로, 세로 길이 조절 가능 (inch 단위)

# %%
plt.figure(figsize=(10,6))

plt.title('3월 기온') 
plt.xlabel('날짜')
plt.ylabel('기온')

plt.plot(temp, 'go--')
plt.show()

# %% [markdown]
# ### 격자 및 수평/수직선 추가하기
# #### 그리드 (grid)
# + grid() 함수의 첫번째 파라미터를 True로 설정하면 그래프에 그리드 (grid)가 표시
# + alpha:  그리드의 투명도를 설정
#  - 0으로 설정하면 투명하게, 1은 불투명하게 표시
# + linestyle : 선의 스타일을 대쉬 (Dashed)로 설정
#
#
# #### 수평 / 수직선 그리기
# + plt.axvline(x, color)
#  - 축을 가로지르는 세로 선 생성
# + plt.axhline(y, color)
#  - 축을 가로지르는 가로 선 생성

# %%
plt.figure(figsize=(10,6)) 

plt.title('3월 기온') 
plt.xlabel('날짜')
plt.ylabel('기온')

plt.plot(temp, 'go--')
plt.grid(True, color='gray', alpha=0.5, linestyle='--')
plt.axhline(y=10, color='r', linewidth=1)
plt.show()

# %% [markdown]
# ### 글자 쓰기
# + plt.text(x, y, s, fontsize)
#  - 원하는 위치에 텍스트 생성

# %%
plt.figure(figsize=(10,6)) 

plt.title('3월 기온') 
plt.xlabel('날짜')
plt.ylabel('기온')

plt.plot(temp, 'go--')
plt.grid(True, color='gray', alpha=0.5, linestyle='--')
plt.axhline(y=10, color='r', linewidth=1)
plt.text(22, 10, '기준')
plt.show()

# %% [markdown]
# ### 그래프 겹쳐 그리기

# %%
plt.figure(figsize=(10,6))
plt.plot(temp, 'g--', label='기본')
plt.plot(temp, 'b-', drawstyle='steps-post', label='계단식')
plt.legend(loc='best')
plt.show()

# %% [markdown]
# ### 여러 그래프 그리기

# %%
x = list(range(1,32))

plt.figure(figsize=(10,6))
plt.subplot(2,2,1)
plt.plot(x,temp, 'go--')
plt.title('기본그래프')

plt.subplot(2,2,2)
plt.scatter(x, temp)
plt.title('산포도그래프')

plt.subplot(2,2,3)
plt.bar(x, temp)
plt.title('막대그래프')
 
plt.subplot(2,2,4)
plt.barh(x,temp)
plt.title('막대그래프')
# Out:
# Text(0.5, 1.0, '막대그래프')

# %%
fig = plt.figure(figsize=(10,6)) 
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)

ax1.plot(temp, 'go--')
ax1.set_title('3월 기온1') 

ax2.plot(temp, 'bx')
ax2.set_title('3월 기온2') 

ax3.plot(temp, 'r+-.')
ax3.set_xlabel('일자')
# Out:
# Text(0.5, 0, '일자')

# %% [markdown]
# ### 혼합그래프

# %%
#혼합그래프
avg = [4.5,6.6,10.5,13.4,19.3,21.1,24.3,27,23.1,18.6,13,7]
min = [-4.4,-4.2,0.5,2.1,11,15.5,19.8,20.3,15.8,10.4,2,-2.8]
max = [13.7,16.5,21,23.4,30.1,29.7,30.9,35,30.5,28.8,24,16.6]


x = list(range(1, len(avg)+1))

plt.figure(figsize=(10,6))

#그래프에서 마이너스 기호가 표시
plt.rcParams['axes.unicode_minus'] = False  
plt.bar(x,avg, label='평균')
plt.plot(x,min, 'g--', label='최소')
plt.plot(x,max, 'r-', label='최대')
plt.legend()
plt.title('기온변화')
plt.xlabel('월')

#그래프 보기
plt.show()

# %% [markdown]
# ### x축 눈금 표시 및 회전

# %%
#혼합그래프
avg = [4.5,6.6,10.5,13.4,19.3,21.1,24.3,27,23.1,18.6,13,7]
xt = list(range(1, 13))
xt = [str(i) + '월' for i in xt] 

plt.figure(figsize=(10,6))
plt.plot(avg, 'go-') 
plt.title('기온변화') 

plt.xticks(range(len(avg)), labels=xt, rotation=90)

#그래프 보기
plt.show()

# %% [markdown]
# # JSON 모듈

# %% [markdown]
# ## **JSON(JavaScript Object Notation)**
# + 데이타를 교환하는 포맷으로 키-값의 쌍으로 이루어진 컬렉션
# + 데이터 포맷이 단순하고 유연함
# + 웹 상에서 데이터를 교환하는 데 많이 사용되고 있음

# %% [markdown]
# ## **Python  JSON 표준 라이브러리**

# %%
import json

# %% [markdown]
# ### **JSON 인코딩**
#
# ```
# json.dumps()
# ```
#
# + Python 타입의 데이터를 JSON 문자열로 변경
# + 딕션너리, 리스트, 튜플을 JSON 문자열로 변경
# + 반환값은 JSON 표현을 갖는 문자열(str 타입)
# + "indent" 옵션
#  - JSON 문자열을 읽기 편하게  Identation이 적용된 문자열 반환
# + 한글 처리
#  - ensure_ascii=False
#
# ```
# json.dumps(파이썬자료, indent=4)
# ```

# %%
jdata = {
    "request_id": "0",
    "return_type": "omAnalysis",
    "result": 0,
    "reason": "",
    "return_object": {
        "query": "한국의 가을은 매우 아름답습니다.",
        "type": "감성분석",
        "score": 0.9999995231628418,
        "label": "긍정"
    },
    "result_code": "success"
}
print(type(jdata))
# Out:
# <class 'dict'>

# %%
#json 문자열 만들기

# %%
#json 문자열 만들기 : \t로 Identation이 적용

# %%
#json 문자열 만들기 : \t로 Identation이 적용, 한글 처리

# %% [markdown]
# ### **JSON 디코딩**
#
#
# ```
# json.loads()
# ```
#
# + JSON 문자열을 딕션너리, 리스트, 튜플과 같은 Python 타입으로 변경

# %%
#json 파일을 읽어서 딕션너리로 저장

# %% [markdown]
# ---
# 해결문제
#
#
# ---
# AI Cloud의 무료 AI 서비스 중 텍스트 감정 분석 결과를 분석하시오.
# (https://www.saltlux.ai/portal/main)
#
# ```python
# 오늘은 날씨가 매우 좋네요.
# 기쁨:0.7789
# 신뢰:0.5116
# ```

# %% [markdown]
# # urllib 모듈
# + URL과 웹 요청에 관련된 모듈들 패키지로 묶어 제공

# %% [markdown]
# ## urllib.request 모듈
# * 웹 페이지 요청 및 데이터를 가져올 수 있음

# %% [markdown]
# ### urllib.request.urlopen(url, data)
# * 웹 서버에 정보를 요청한 후, 돌려받은 응답을 저장하여 ‘응답 객체(HTTPResponse)’를 반환
# * data는 서버로 전송할 추가 데이터를 지정하는 객체
# * 반환된 응답 객체:  read() 메서드를 실행
#    - 웹 서버가 응답한 데이터를 바이트 배열로 읽어들임
#    - 읽어들인 바이트 배열 : 이진수로 이루어진 수열이어서 **텍스트 형식의 데이터를 decode('utf-8') 메서드를 실행하여 문자열로 변환**
#
# * 참고) **Byte 데이터**
#   + 1바이트(0~255사이 코드)로 표현되는 문자 표현
#   + 문자열에서 사용하는 연산을 거의 제공
#     - 인덱싱/슬라이싱, in, Upper(), Split()
#   + 지원 메소드
#     - **decode(인코딩값)** : 바이트->문자열로 변환
#     - **encode()** : 문자열->바이트로 변환

# %% [markdown]
# ### urllib.request.Request(url, headers={})
# * URL 요청의 추상화
# * headers : 딕셔너리

# %%
from urllib.request import Request, urlopen
import json

# %%
#질문 입력 
query = input()
# Out:
# 하늘이 매우 맑네요

# %%
url = "http://svc.saltlux.ai:31781"
headers={"Content-Type":"application/json" } 

apiKey = ""
rqData = {
    "key": apiKey,
    "serviceId": "11987300804",
    "argument": {
        "type": "1",
        "query":  query
    }
}

# %%
#POST 방식으로 데이터 전송 위해 
req = Request(url, headers=headers)
jdata = json.dumps(rqData).encode('utf-8')    
response = urlopen(req, jdata)

# %% [markdown]
# ---
# ## 해결문제
#
#
# ---
#
# 평점.txt 파일을 읽어서 리뷰의 내용을 감성분석(긍정,부정,중립)하여 각 결과를 그래프로 나타내시오.

# %%
# 파일 읽기
with open('/content/drive/MyDrive/AIData/data/평점.txt', 'r') as fp :
 data = fp.readlines()

# %%
from urllib.request import Request, urlopen
import json

# %%
# ai cloud 함수로 만들기 
def aicloud(msg) :

# %% [markdown]
# # Beautiful Soup 모듈
# + HTML 및 XML 문서 를 구문 분석하기 위한 Python 패키지
# + DOM 추출
# + 기본적으로 UTF-8 인코딩 방식이지만 CP949도 지원

# %% [markdown]
# ## 웹 크롤링(web crawling)
# + 인터넷 상에 존재하는 자료를  수집하여 데이터를 파싱하여 원하는 정보를 추출하는 것

# %%
from urllib.request import urlopen

# %%
webpage = urlopen('https://movie.daum.net/ranking/reservation').read().decode('utf-8')
print(webpage)

# %% [markdown]
# ## BeautifulSoup 모듈 웹페이지 파싱
# ### 1. 객체 생성
# ```python
# from bs4 import BeautifulSoup as bs
#
# 인스턴스명 = BeautifulSoup(markup, parser)
# ```
# * 첫 번째 인자 : HTML 형식의 문자열
# * 두 번째 인자 : 첫 번째 인자의 문자열을 해석하기 위한 파서
#
#   * **파서(parser) 종류**
#     + html.parser : 파이썬 표준 라이브러리에 포함된 파서로 빠르지만 유연하지 않기 때문에 단순한 HTML문서에 사용
#
#         ```
#         BeautifulSoup(markup, "html.parser")
#         ```
#
#     + lxml : 매우 빠르고 유연하지만 외부 의존
#       - lxml의 HTML 파서
#           ```
#           BeautifulSoup(markup, "lxml")
#           ```
#       - lxml의 XML 파서
#           ```
#           BeautifulSoup(markup, "lxml-xml")
#           ```
#
#     + html5lib : 웹 브라우저와 동일한 방식으로 페이지 구문 분석하는 파서로 매우 느리지만 매우 유연하지만 외부 의존
#         ```
#         BeautifulSoup(markup, "html5lib")
#       ```

# %%
from bs4 import BeautifulSoup as bs

html = bs(webpage, 'html.parser')

# %% [markdown]
# ### 2. **Beautiful Soup 파싱 메소드**
# + 태그명
#   + **.find(태그명)** : 조건에 맞는 태그 1개만 찾음
#   + **.find_all(태그명)** : 조건에 맞는 모든 태그 찾음
# + css선택자
#   + **.select_one(선택자)** : 조건에 맞는 CSS선택자 1개만 찾음
#   + **.select(선택자)** : 조건에 맞는 CSS선택자 찾음

# %%
#영화 목록 가져오기

# %% [markdown]
# ---
# ## 해결문제
#
#
# ---
#
# 다음 많이 본 뉴스를 크롤링하여 감성분석 결과를 그래프로 그리시오.
# (https://news.daum.net/ranking/popular)
#
# 1. 웹페이지 크롤링
# 2. 크롤링한 자료를 파일로 저장
# 3. 파일의 내용을 읽어서 ai api를 이용하여 감성분석결과를 정리
# 4. 그래프 그리기

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup as bs

webpage = urlopen('https://news.daum.net/ranking/popular').read().decode('utf-8')
html = bs(webpage, 'html.parser')
